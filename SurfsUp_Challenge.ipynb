# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
target = dt.date(2022,1,1)
results = session.query(Measurement.tobs, Measurement.date).\
filter (Measurement.date <= dt.date(2010,6,1)).all()
df=pd.DataFrame(results, columns=['tobs','Date'])
print(df)
# Out:
#       tobs        Date
# 0     65.0  2010-01-01
# 1     63.0  2010-01-02
# 2     74.0  2010-01-03
# 3     76.0  2010-01-04
# 4     73.0  2010-01-06
# ...    ...         ...
# 1082  71.0  2010-05-26
# 1083  72.0  2010-05-27
# 1084  74.0  2010-05-28
# 1085  80.0  2010-05-31
# 1086  70.0  2010-06-01
#
# [1087 rows x 2 columns]

# %%
dates = session.query(Measurement.date).all()

((dates[0][0])
# Out:
# '2010-01-01'

# %%
#  3. Convert the June temperatures to a list.
june_temps = df['tobs'].values.tolist()
june_temps
# Out:
# [65.0,
#  63.0,
#  74.0,
#  76.0,
#  73.0,
#  70.0,
#  64.0,
#  68.0,
#  73.0,
#  64.0,
#  61.0,
#  66.0,
#  65.0,
#  68.0,
#  64.0,
#  72.0,
#  66.0,
#  66.0,
#  69.0,
#  67.0,
#  67.0,
#  71.0,
#  67.0,
#  76.0,
#  68.0,
#  72.0,
#  70.0,
#  67.0,
#  66.0,
#  67.0,
#  69.0,
#  67.0,
#  67.0,
#  64.0,
#  69.0,
#  73.0,
#  73.0,
#  69.0,
#  69.0,
#  69.0,
#  71.0,
#  61.0,
#  69.0,
#  63.0,
#  64.0,
#  65.0,
#  67.0,
#  68.0,
#  65.0,
#  76.0,
#  75.0,
#  66.0,
#  70.0,
#  72.0,
#  73.0,
#  70.0,
#  71.0,
#  72.0,
#  72.0,
#  69.0,
#  70.0,
#  73.0,
#  72.0,
#  73.0,
#  70.0,
#  71.0,
#  68.0,
#  70.0,
#  72.0,
#  69.0,
#  68.0,
#  74.0,
#  72.0,
#  72.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  74.0,
#  74.0,
#  71.0,
#  72.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  73.0,
#  73.0,
#  71.0,
#  71.0,
#  68.0,
#  70.0,
#  71.0,
#  74.0,
#  71.0,
#  75.0,
#  76.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  73.0,
#  74.0,
#  76.0,
#  76.0,
#  80.0,
#  74.0,
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
June_Temps = pd.DataFrame(june_temps, columns=["June Temps"])
June_Temps
# Out:
#       June Temps
# 0           65.0
# 1           63.0
# 2           74.0
# 3           76.0
# 4           73.0
# ...          ...
# 1082        71.0
# 1083        72.0
# 1084        74.0
# 1085        80.0
# 1086        70.0
#
# [1087 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
June_Temps.describe()
# Out:
#         June Temps
# count  1087.000000
# mean     70.470101
# std       4.086178
# min      56.000000
# 25%      68.000000
# 50%      71.000000
# 75%      73.000000
# max      81.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_results = session.query(Measurement.tobs, Measurement.date).\
filter (Measurement.date <= dt.date(2010,12,1)).all()
dec_df=pd.DataFrame(results, columns=['tobs','Date'])
print(dec_df)
# Out:
#       tobs        Date
# 0     65.0  2010-01-01
# 1     63.0  2010-01-02
# 2     74.0  2010-01-03
# 3     76.0  2010-01-04
# 4     73.0  2010-01-06
# ...    ...         ...
# 1082  71.0  2010-05-26
# 1083  72.0  2010-05-27
# 1084  74.0  2010-05-28
# 1085  80.0  2010-05-31
# 1086  70.0  2010-06-01
#
# [1087 rows x 2 columns]

# %%
# 7. Convert the December temperatures to a list.
dec_temps = dec_df['tobs'].values.tolist()
dec_temps
# Out:
# [65.0,
#  63.0,
#  74.0,
#  76.0,
#  73.0,
#  70.0,
#  64.0,
#  68.0,
#  73.0,
#  64.0,
#  61.0,
#  66.0,
#  65.0,
#  68.0,
#  64.0,
#  72.0,
#  66.0,
#  66.0,
#  69.0,
#  67.0,
#  67.0,
#  71.0,
#  67.0,
#  76.0,
#  68.0,
#  72.0,
#  70.0,
#  67.0,
#  66.0,
#  67.0,
#  69.0,
#  67.0,
#  67.0,
#  64.0,
#  69.0,
#  73.0,
#  73.0,
#  69.0,
#  69.0,
#  69.0,
#  71.0,
#  61.0,
#  69.0,
#  63.0,
#  64.0,
#  65.0,
#  67.0,
#  68.0,
#  65.0,
#  76.0,
#  75.0,
#  66.0,
#  70.0,
#  72.0,
#  73.0,
#  70.0,
#  71.0,
#  72.0,
#  72.0,
#  69.0,
#  70.0,
#  73.0,
#  72.0,
#  73.0,
#  70.0,
#  71.0,
#  68.0,
#  70.0,
#  72.0,
#  69.0,
#  68.0,
#  74.0,
#  72.0,
#  72.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  74.0,
#  74.0,
#  71.0,
#  72.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  73.0,
#  73.0,
#  71.0,
#  71.0,
#  68.0,
#  70.0,
#  71.0,
#  74.0,
#  71.0,
#  75.0,
#  76.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  73.0,
#  74.0,
#  76.0,
#  76.0,
#  80.0,
#  74.0,
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
Dec_Temps = pd.DataFrame(dec_temps, columns=["Dec Temps"])
Dec_Temps
# Out:
#       Dec Temps
# 0          65.0
# 1          63.0
# 2          74.0
# 3          76.0
# 4          73.0
# ...         ...
# 1082       71.0
# 1083       72.0
# 1084       74.0
# 1085       80.0
# 1086       70.0
#
# [1087 rows x 1 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
Dec_Temps.describe()
# Out:
#          Dec Temps
# count  1087.000000
# mean     70.470101
# std       4.086178
# min      56.000000
# 25%      68.000000
# 50%      71.000000
# 75%      73.000000
# max      81.000000
